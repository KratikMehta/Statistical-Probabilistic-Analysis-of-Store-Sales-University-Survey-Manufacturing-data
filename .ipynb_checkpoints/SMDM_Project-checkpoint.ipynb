# %%
# %matplotlib inline
# %precision 3

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib_inline
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

matplotlib_inline.backend_inline.set_matplotlib_formats('pdf', 'svg')
plt.style.use('ggplot')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# # Problem 1

# %% [markdown]
# A wholesale distributor operating in different regions of Portugal has information on annual spending of several items in their stores across different regions and channels. The data consists of 440 large retailers’ annual spending on 6 different varieties of products in 3 different regions (Lisbon, Oporto, Other) and across different sales channel (Hotel, Retail).

# %% [markdown]
# ## Sample of the Wholesale Customers Dataset

# %%
wholesale_df = pd.read_csv('Wholesale+Customers+Data.csv')
wholesale_df.head()
# Out:
#    Buyer/Spender Channel Region  Fresh  Milk  Grocery  Frozen  \
# 0              1  Retail  Other  12669  9656     7561     214
# 1              2  Retail  Other   7057  9810     9568    1762
# 2              3  Retail  Other   6353  8808     7684    2405
# 3              4   Hotel  Other  13265  1196     4221    6404
# 4              5  Retail  Other  22615  5410     7198    3915
#
#    Detergents_Paper  Delicatessen
# 0              2674          1338
# 1              3293          1776
# 2              3516          7844
# 3               507          1788
# 4              1777          5185

# %% [markdown]
# ## Checking the types of variables in the dataset.

# %%
wholesale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Buyer/Spender     440 non-null    int64
#  1   Channel           440 non-null    object
#  2   Region            440 non-null    object
#  3   Fresh             440 non-null    int64
#  4   Milk              440 non-null    int64
#  5   Grocery           440 non-null    int64
#  6   Frozen            440 non-null    int64
#  7   Detergents_Paper  440 non-null    int64
#  8   Delicatessen      440 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 31.1+ KB

# %% [markdown]
# From the above output we can see that:
# - There are 440 observations of different buyers in the data.
# - There are 9 variables, out of which, 7 are of integer type and 2 are of object(categorical) type.
# - Out of the 7 integer type variables, __Buyer/Spender__ is _discrete numerical variable_ while the others are _continous numerical variables_.
# - The dataset does not have any missing values.

# %% [markdown]
# ## Checking the distributions of the continous variables.

# %%
wholesale_df.hist(column=['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicatessen'], 
                  figsize=(14, 7), bins=50, layout=(2, 3))
plt.figtext(s='Distribution of Continous Variables', x=0.5, y=1, ha='center', size='xx-large')
plt.tight_layout();

# %% [markdown]
# - From the above plot, it can be seen that the data for the continous variables is not normally distributed.

# %% [markdown]
# ## 1.1 Use methods of descriptive statistics to summarize data. Which Region and which Channel spent the most? Which Region and which Channel spent the least?

# %% [markdown]
# ### Descriptive Statistics of the Wholesale Customers Dataset

# %% [markdown]
# Descriptive Statistics tells us a brief summary of the dataset. It can include the 5-point summary for the numerical variables and frequency distribution of categotical variables.

# %%
wholesale_df.describe(include='all').T
# Out:
#                   count unique    top freq          mean           std   min  \
# Buyer/Spender     440.0    NaN    NaN  NaN         220.5    127.161315   1.0
# Channel             440      2  Hotel  298           NaN           NaN   NaN
# Region              440      3  Other  316           NaN           NaN   NaN
# Fresh             440.0    NaN    NaN  NaN  12000.297727  12647.328865   3.0
# Milk              440.0    NaN    NaN  NaN   5796.265909   7380.377175  55.0
# Grocery           440.0    NaN    NaN  NaN   7951.277273   9503.162829   3.0
# Frozen            440.0    NaN    NaN  NaN   3071.931818   4854.673333  25.0
# Detergents_Paper  440.0    NaN    NaN  NaN   2881.493182   4767.854448   3.0
# Delicatessen      440.0    NaN    NaN  NaN   1524.870455   2820.105937   3.0
#
#                       25%     50%       75%       max
# Buyer/Spender      110.75   220.5    330.25     440.0
# Channel               NaN     NaN       NaN       NaN
# ...

# %% [markdown]
# From the above output we can see that:
# - The __Channel__ variable has 2 unique values, with $\color{red}{\textit{Hotel}}$ being the most frequent, occuring 298 times.
# - The __Region__ variable has 3 unique values, with $\color{red}{\textit{Other}}$ being the most frequent, occuring 316 times.
# - The __Fresh__ items have the highest average annual spendings in the dataset.
# - The maximum annual spending values of all the items are quite high. These values might be outliers.
# - The standard deviations of the annual spendings are also large. This indicates that the data is spread over s big range.
#
# NaN shows that the values cannot be calculated for that particular variable. Like we cannot calculate mean for a categorical variable. And in a same way unique value cannot be calculated for a numerical variable.

# %% [markdown]
# ### Region wise Total Annual Spendings for the items

# %%
wholesale_df['Total_Spendings'] = wholesale_df.eval('Fresh + Milk + Grocery + Frozen + Detergents_Paper + Delicatessen')
region_vs_total_spendings = wholesale_df.groupby('Region')[['Total_Spendings']].sum().sort_values(by='Total_Spendings')
region_vs_total_spendings
# Out:
#         Total_Spendings
# Region
# Oporto          1555088
# Lisbon          2386813
# Other          10677599

# %%
plt.figure(figsize=(7, 5))
sns.barplot(data=region_vs_total_spendings, y='Total_Spendings', x=region_vs_total_spendings.index)
plt.title('Region wise Total Spendings')
plt.ylabel('Total Spendings')
plt.yticks(labels=['0', '2000000', '4000000', '6000000', '8000000', '10000000', '12000000'], 
           ticks=np.linspace(0, 12000000, 7));

# %% [markdown]
# After calculating the Region wise Total Spendings, we found that:
# - The buyers spent the $\color{red}{\textit{least}}$ in the $\color{red}{\textit{Oporto}}$ region.
# - The buyers spent the $\color{green}{\textit{most}}$ in the $\color{green}{\textit{Other}}$ regions.

# %% [markdown]
# ### Channel wise Total Annual Spendings for the items

# %%
channel_vs_total_spendings = wholesale_df.groupby('Channel')[['Total_Spendings']].sum().sort_values(by='Total_Spendings')
channel_vs_total_spendings
# Out:
#          Total_Spendings
# Channel
# Retail           6619931
# Hotel            7999569

# %%
plt.figure(figsize=(7, 5))
sns.barplot(data=channel_vs_total_spendings, y='Total_Spendings', x=channel_vs_total_spendings.index)
plt.title('Channel wise Total Spendings')
plt.ylabel('Total Spendings')
plt.yticks(labels=['0', '2000000', '4000000', '6000000', '8000000'], 
           ticks=np.linspace(0, 8000000, 5));

# %% [markdown]
# After calculating the Channel wise Total Spendings, we found that:
# - The retailers spent the $\color{red}{\textit{least}}$ in the $\color{red}{\textit{Retail}}$ channels.
# - The retailers spent the $\color{green}{\textit{most}}$ in the $\color{green}{\textit{Hotel}}$ channels.

# %% [markdown]
# ## 1.2 There are 6 different varieties of items that are considered. Describe and comment/explain all the varieties across Region and Channel? Provide a detailed justification for your answer.

# %% [markdown]
# ### Region wise Average spendings for different variety of Items.

# %%
items = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicatessen']
region_vs_items_mean = wholesale_df.groupby('Region')[items].mean()
region_vs_items_std = wholesale_df.groupby('Region')[items].std()
region_vs_items_mean
# Out:
#                Fresh         Milk      Grocery       Frozen  Detergents_Paper  \
# Region
# Lisbon  11101.727273  5486.415584  7403.077922  3000.337662       2651.116883
# Oporto   9887.680851  5088.170213  9218.595745  4045.361702       3687.468085
# Other   12533.471519  5977.085443  7896.363924  2944.594937       2817.753165
#
#         Delicatessen
# Region
# Lisbon   1354.896104
# Oporto   1159.702128
# Other    1620.601266

# %% [markdown]
# ### Region wise Coefficient of Variation of spendings for different variety of Items.

# %% [markdown]
# Coefficient of Variations is a measure of relative dispersion around the mean. It is used to compare variables with different ranges and units of measurments.

# %%
region_vs_items_cv = region_vs_items_std / region_vs_items_mean
region_vs_items_cv
# Out:
#            Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# Region
# Lisbon  1.041049  1.039815  1.147670  1.030599          1.587430      0.993008
# Oporto  0.848318  1.145076  1.176182  2.262291          1.766718      0.906043
# Other   1.068277  1.327648  1.207808  1.446761          1.630040      1.994680

# %% [markdown]
# From the above tables we can conclude that:
# - For all the Regions in Portugal :-
#     * Highest Averages spendings are for $\color{green}{\textit{Fresh}}$ items.
#     * Lowest Averages spendings are for $\color{red}{\textit{Delicatessen}}$ items. This means that people spend less on expensive food stores.
#     * In general, spendings for all the items are largely spread out around the mean.
# - In Lisbon :-
#     * The spendings for __Detergents_Paper__ is highly spread out about its mean in comparison to other items. This could mean that the actual spendings for __Detergents_Paper__ are away from its mean and near the extreme values.
# - In Oporto :-
#     * The spendings for __Frozen__ items is highly spread out about its mean in comparison to other items. This could mean that the actual spendings for __Frozen__ are away from its mean and near the extreme values.
# - In Other regions :-
#     * The spendings for __Delicatessen__ is highly spread out about its mean in comparison to other items. This could mean that the actual spendings for __Delicatessen__ are away from its mean and near the extreme values.

# %% [markdown]
# ### Channel wise Average spendings for different variety of Items.

# %%
channel_vs_items_mean = wholesale_df.groupby('Channel')[items].mean()
channel_vs_items_std = wholesale_df.groupby('Channel')[items].std()
channel_vs_items_mean
# Out:
#                 Fresh          Milk       Grocery       Frozen  \
# Channel
# Hotel    13475.560403   3451.724832   3962.137584  3748.251678
# Retail    8904.323944  10716.500000  16322.852113  1652.612676
#
#          Detergents_Paper  Delicatessen
# Channel
# Hotel          790.560403   1415.956376
# Retail        7269.507042   1753.436620

# %% [markdown]
# ### Channel wise Coefficient of Variation of spendings for different variety of Items.

# %%
channel_vs_items_cv = channel_vs_items_std / channel_vs_items_mean
channel_vs_items_cv
# Out:
#             Fresh      Milk   Grocery    Frozen  Detergents_Paper  \
# Channel
# Hotel    1.026428  1.260867  0.894849  1.505745          1.396596
# Retail   1.009365  0.903246  0.751543  1.096932          0.865408
#
#          Delicatessen
# Channel
# Hotel        2.222828
# Retail       1.114267

# %% [markdown]
# From the above tables we can conclude that:
# - For all the Channels in Portugal :-
#     * In general, spendings for all the items are largely spread out around the mean.
# - For Hotels in Portugal :-
#     * Highest Averages spendings are for $\color{green}{\textit{Fresh}}$ items.
#     * Lowest Averages spendings are for $\color{red}{\textit{Detergents Papers}}$.
#     * The spendings for __Delicatessen__ is highly spread out about its mean in comparison to other items. This could mean that most of the values are less than the mean while only few are more than the mean.
# - For Retail outlets in Portugal :-
#     * Highest Averages spendings are for $\color{green}{\textit{Grocery}}$ items.
#     * Lowest Averages spendings are for $\color{red}{\textit{Frozen}}$ items.
#     * The spendings for __Delicatessen__ items is highly spread out about its mean in comparison to other items. This could mean that most of the values are less than the mean while only few are more than the mean.

# %% [markdown]
# ## 1.3 On the basis of a descriptive measure of variability, which item shows the most inconsistent behaviour? Which items show the least inconsistent behaviour?

# %% [markdown]
# Using the Coefficient of Variation (CV) as a measure of variability, as the means of all the items are highly different.

# %%
items_df = wholesale_df[items]
items_cv = items_df.std() / items_df.mean()
items_cv
# Out:
# Fresh               1.053918
# Milk                1.273299
# Grocery             1.195174
# Frozen              1.580332
# Detergents_Paper    1.654647
# Delicatessen        1.849407
# dtype: float64

# %% [markdown]
# From the above table we can see that:
# - __Delicatessen__ items show the most inconsistent behaviour as its CV is very high.
# - __Fresh__ items show the least inconsistent behaviour as its CV is very low.

# %% [markdown]
# ## 1.4 Are there any outliers in the data? Back up your answer with a suitable plot/technique with the help of detailed comments.

# %% [markdown]
# Box Plot is a very effective visualization to detect outliers.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=wholesale_df[items], fliersize=3)
plt.xlabel('Items')
plt.ylabel('Spendings')
plt.title('Itemwise Box Plots');

# %% [markdown]
# From the above box plot we can see that the spendings for all the items in the dataset have outliers. The plot also confirms that the spendings are Positively skewed as the spread of data above the median is more than spread of data below the median. These outliers can be buyers who buy in large quantities at once or buyers who buy expensive items.

# %% [markdown]
# ## 1.5 On the basis of your analysis, what are your recommendations for the business? How can your analysis help the business to solve its problem? Answer from the business perspective

# %% [markdown]
# - From the above histograms we can see that, most of the buyers spend less for all items. So the wholesaler can keep more stock of reasonable items as compared to expensive items to meet demand expectations.
# - __Fresh__ items are the most popular items bought by the customers. Keeping higher stock of the items might help increase sales and meet demands.
# - __Delicatessen__ items are the least bought items. Reducing the stock of these items will help decrease inventory costs.
# - __Oporto__ region has the lowest annual spendings. Increasing the stock of __Fresh__ and __Grocery__ items in this region might help increase sales.
# - In __Lisbon__ region, __Detegent Paper__ and __Delicatessen__ items have the lowest sales. Reducing their stocks will help decrease inventory.
# - The __Other__ regions combined have the highest sales. Increasing the customer base and keeping the prices reasonable can help increase sales and profit in this region.
# - For __Hotel__ channels, providing offers on __Detegent Paper__ and __Delicatessen__ can help increase sales of these items. Also keeping high stocks of __Fresh__ items will help meet demand expectations.
# - For __Retail__ channels, providing offers on __Frozen__ and __Delicatessen__ can help increase sales of these items. Also keeping high stocks of __Milk__ and __Grocery__ items will help meet demand expectations.

# %% [markdown]
# # Problem 2

# %% [markdown]
# The Student News Service at Clear Mountain State University (CMSU) has decided to gather data about the undergraduate students that attend CMSU. CMSU creates and distributes a survey of 14 questions and receives responses from 62 undergraduates (stored in the __Survey__ data set).

# %% [markdown]
# ## Sample of the Survey Dataset

# %%
survey_df = pd.read_csv('Survey-1.csv')
survey_df.head()
# Out:
#    ID  Gender  Age   Class       Major Grad Intention  GPA  Employment  \
# 0   1  Female   20  Junior       Other            Yes  2.9   Full-Time
# 1   2    Male   23  Senior  Management            Yes  3.6   Part-Time
# 2   3    Male   21  Junior       Other            Yes  2.5   Part-Time
# 3   4    Male   21  Junior         CIS            Yes  2.5   Full-Time
# 4   5    Male   23  Senior       Other      Undecided  2.8  Unemployed
#
#    Salary  Social Networking  Satisfaction  Spending Computer  Text Messages
# 0    50.0                  1             3       350   Laptop            200
# 1    25.0                  1             4       360   Laptop             50
# 2    45.0                  2             4       600   Laptop            200
# 3    40.0                  4             6       600   Laptop            250
# 4    40.0                  2             4       500   Laptop            100

# %% [markdown]
# ## Checking the types of variables in the dataset.

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 62 non-null     int64
#  1   Gender             62 non-null     object
#  2   Age                62 non-null     int64
#  3   Class              62 non-null     object
#  4   Major              62 non-null     object
#  5   Grad Intention     62 non-null     object
#  6   GPA                62 non-null     float64
#  7   Employment         62 non-null     object
#  8   Salary             62 non-null     float64
#  9   Social Networking  62 non-null     int64
#  10  Satisfaction       62 non-null     int64
#  11  Spending           62 non-null     int64
#  12  Computer           62 non-null     object
#  13  Text Messages      62 non-null     int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 6.9+ KB

# %% [markdown]
# From the above output we can see that:
# - There are 62 observations from different students in the data.
# - There are 14 variables, out of which, 6 are of integer type, 2 are of float type and 6 are of object(categorical) type.
# - The dataset does not have any missing values.

# %% [markdown]
# ## 2.1. For this data, construct the following contingency tables (Keep Gender as row variable)

# %% [markdown]
# ### 2.1.1. Gender and Major

# %%
gender_vs_major = pd.crosstab(index=survey_df['Gender'], columns=survey_df['Major'], margins=True, margins_name='Total')
gender_vs_major
# Out:
# Major   Accounting  CIS  Economics/Finance  International Business  \
# Gender
# Female           3    3                  7                       4
# Male             4    1                  4                       2
# Total            7    4                 11                       6
#
# Major   Management  Other  Retailing/Marketing  Undecided  Total
# Gender
# Female           4      3                    9          0     33
# Male             6      4                    5          3     29
# Total           10      7                   14          3     62

# %% [markdown]
# ### 2.1.2. Gender and Grad Intention

# %%
gender_vs_grad_intent = pd.crosstab(index=survey_df['Gender'], columns=survey_df['Grad Intention'], margins=True, margins_name='Total')
gender_vs_grad_intent
# Out:
# Grad Intention  No  Undecided  Yes  Total
# Gender
# Female           9         13   11     33
# Male             3          9   17     29
# Total           12         22   28     62

# %% [markdown]
# ### 2.1.3. Gender and Employment

# %%
gender_vs_employment = pd.crosstab(index=survey_df['Gender'], columns=survey_df['Employment'], margins=True, margins_name='Total')
gender_vs_employment
# Out:
# Employment  Full-Time  Part-Time  Unemployed  Total
# Gender
# Female              3         24           6     33
# Male                7         19           3     29
# Total              10         43           9     62

# %% [markdown]
# ### 2.1.4. Gender and Computer

# %%
gender_vs_computer = pd.crosstab(index=survey_df['Gender'], columns=survey_df['Computer'], margins=True, margins_name='Total')
gender_vs_computer
# Out:
# Computer  Desktop  Laptop  Tablet  Total
# Gender
# Female          2      29       2     33
# Male            3      26       0     29
# Total           5      55       2     62

# %% [markdown]
# ## 2.2. Assume that the sample is representative of the population of CMSU. Based on the data, answer the following question:

# %% [markdown]
# ### 2.2.1. What is the probability that a randomly selected CMSU student will be male?

# %%
male_prob = 29 / 62 * 100
print(f"Out of the total 62 students, 29 students are male.\n"
      f"Hence the probability that a randomly selected CMSU student will be male is {round(male_prob, 2)}%.")
# Out:
# Out of the total 62 students, 29 students are male.
# Hence the probability that a randomly selected CMSU student will be male is 46.77%.

# %% [markdown]
# ### 2.2.2. What is the probability that a randomly selected CMSU student will be female?

# %%
female_prob = 33 / 62 * 100
print(f"Out of the total 62 students, 33 students are female.\n"
      f"Hence the probability that a randomly selected CMSU student will be female is {round(female_prob, 2)}%.")
# Out:
# Out of the total 62 students, 33 students are female.
# Hence the probability that a randomly selected CMSU student will be female is 53.23%.

# %% [markdown]
# ## 2.3. Assume that the sample is representative of the population of CMSU. Based on the data, answer the following question:

# %% [markdown]
# ### 2.3.1. Find the conditional probability of different majors among the male students in CMSU.

# %%
account_male_prob = gender_vs_major.loc['Male', 'Accounting'] / gender_vs_major.loc['Male', 'Total'] * 100
cis_male_prob = gender_vs_major.loc['Male', 'CIS'] / gender_vs_major.loc['Male', 'Total'] * 100
economics_male_prob = gender_vs_major.loc['Male', 'Economics/Finance'] / gender_vs_major.loc['Male', 'Total'] * 100
business_male_prob = gender_vs_major.loc['Male', 'International Business'] / gender_vs_major.loc['Male', 'Total'] * 100
manage_male_prob = gender_vs_major.loc['Male', 'Management'] / gender_vs_major.loc['Male', 'Total'] * 100
other_male_prob = gender_vs_major.loc['Male', 'Other'] / gender_vs_major.loc['Male', 'Total'] * 100
market_male_prob = gender_vs_major.loc['Male', 'Retailing/Marketing'] / gender_vs_major.loc['Male', 'Total'] * 100
undecided_male_prob = gender_vs_major.loc['Male', 'Undecided'] / gender_vs_major.loc['Male', 'Total'] * 100

# %%
print(f"Conditional probability that a Male student has an Accounting major is {round(account_male_prob, 2)}%.")
print(f"Conditional probability that a Male student has a CIS major is {round(cis_male_prob, 2)}%.")
print(f"Conditional probability that a Male student has an Economics/Finance major is {round(economics_male_prob, 2)}%.")
print(f"Conditional probability that a Male student has an International Business major is {round(business_male_prob, 2)}%.")
print(f"Conditional probability that a Male student has a Management major is {round(manage_male_prob, 2)}%.")
print(f"Conditional probability that a Male student has Other major is {round(other_male_prob, 2)}%.")
print(f"Conditional probability that a Male student has a Retailing/Marketing major is {round(market_male_prob, 2)}%.")
print(f"Conditional probability that a Male student has an Undecided major is {round(undecided_male_prob, 2)}%.")
# Out:
# Conditional probability that a Male student has an Accounting major is 13.79%.
# Conditional probability that a Male student has a CIS major is 3.45%.
# Conditional probability that a Male student has an Economics/Finance major is 13.79%.
# Conditional probability that a Male student has an International Business major is 6.9%.
# Conditional probability that a Male student has a Management major is 20.69%.
# Conditional probability that a Male student has Other major is 13.79%.
# Conditional probability that a Male student has a Retailing/Marketing major is 17.24%.
# Conditional probability that a Male student has an Undecided major is 10.34%.

# %% [markdown]
# ### 2.3.2. Find the conditional probability of different majors among the female students in CMSU.

# %%
account_female_prob = gender_vs_major.loc['Female', 'Accounting'] / gender_vs_major.loc['Female', 'Total'] * 100
cis_female_prob = gender_vs_major.loc['Female', 'CIS'] / gender_vs_major.loc['Female', 'Total'] * 100
economics_female_prob = gender_vs_major.loc['Female', 'Economics/Finance'] / gender_vs_major.loc['Female', 'Total'] * 100
business_female_prob = gender_vs_major.loc['Female', 'International Business'] / gender_vs_major.loc['Female', 'Total'] * 100
manage_female_prob = gender_vs_major.loc['Female', 'Management'] / gender_vs_major.loc['Female', 'Total'] * 100
other_female_prob = gender_vs_major.loc['Female', 'Other'] / gender_vs_major.loc['Female', 'Total'] * 100
market_female_prob = gender_vs_major.loc['Female', 'Retailing/Marketing'] / gender_vs_major.loc['Female', 'Total'] * 100
undecided_female_prob = gender_vs_major.loc['Female', 'Undecided'] / gender_vs_major.loc['Female', 'Total'] * 100

# %%
print(f"Conditional probability that a Female student has an Accounting major is {round(account_female_prob, 2)}%.")
print(f"Conditional probability that a Female student has a CIS major is {round(cis_female_prob, 2)}%.")
print(f"Conditional probability that a Female student has an Economics/Finance major is {round(economics_female_prob, 2)}%.")
print(f"Conditional probability that a Female student has an International Business major is {round(business_female_prob, 2)}%.")
print(f"Conditional probability that a Female student has a Management major is {round(manage_female_prob, 2)}%.")
print(f"Conditional probability that a Female student has Other major is {round(other_female_prob, 2)}%.")
print(f"Conditional probability that a Female student has a Retailing/Marketing major is {round(market_female_prob, 2)}%.")
print(f"Conditional probability that a Female student has an Undecided major is {round(undecided_female_prob, 2)}%.")
# Out:
# Conditional probability that a Female student has an Accounting major is 9.09%.
# Conditional probability that a Female student has a CIS major is 9.09%.
# Conditional probability that a Female student has an Economics/Finance major is 21.21%.
# Conditional probability that a Female student has an International Business major is 12.12%.
# Conditional probability that a Female student has a Management major is 12.12%.
# Conditional probability that a Female student has Other major is 9.09%.
# Conditional probability that a Female student has a Retailing/Marketing major is 27.27%.
# Conditional probability that a Female student has an Undecided major is 0.0%.

# %% [markdown]
# ## 2.4. Assume that the sample is a representative of the population of CMSU. Based on the data, answer the following question:

# %% [markdown]
# ### 2.4.1. Find the probability that a randomly chosen student is a male and intends to graduate.

# %%
grad_yes_male = gender_vs_grad_intent.loc['Male', 'Yes'] / 62 * 100
print(f"Out of the 62 students, 17 students are male who intends to graduate.\n"
      f"Hence the probability that a randomly chosen student is a male and intends to graduate is {round(grad_yes_male, 2)}%.")
# Out:
# Out of the 62 students, 17 students are male who intends to graduate.
# Hence the probability that a randomly chosen student is a male and intends to graduate is 27.42%.

# %% [markdown]
# ### 2.4.2 Find the probability that a randomly selected student is a female and does NOT have a laptop.

# %%
no_laptop_female = gender_vs_computer.loc['Female', ['Desktop', 'Tablet']].sum() / 62 * 100
print(f"Out of the 62 students, 4 students are female who do not have a laptop.\n"
      f"Hence the probability that a randomly chosen student is a female and does NOT have a laptop is {round(no_laptop_female, 2)}%.")
# Out:
# Out of the 62 students, 4 students are female who do not have a laptop.
# Hence the probability that a randomly chosen student is a female and does NOT have a laptop is 6.45%.

# %% [markdown]
# ## 2.5. Assume that the sample is representative of the population of CMSU. Based on the data, answer the following question:

# %% [markdown]
# ### 2.5.1. Find the probability that a randomly chosen student is a male or has full-time employment?

# %% [markdown]
# $$ P(A \cup B) = P(A) + P(B) - P(A \cap B) $$

# %%
full_time_male = (gender_vs_employment.loc['Male', 'Total'] + 
                  gender_vs_employment.loc['Total', 'Full-Time'] - 
                  gender_vs_employment.loc['Male', 'Full-Time']) / 62 * 100
print(f"Out of the 62 students, 29 are male, 10 have full time jobs, and 7 are both male and have full time jobs.\n"
      f"Hence the probability that a randomly chosen student is a male or has full-time employment is {round(full_time_male, 2)}%.")
# Out:
# Out of the 62 students, 29 are male, 10 have full time jobs, and 7 are both male and have full time jobs.
# Hence the probability that a randomly chosen student is a male or has full-time employment is 51.61%.

# %% [markdown]
# ### 2.5.2. Find the conditional probability that given a female student is randomly chosen, she is majoring in international business or management.

# %% [markdown]
# For mutualy exclusive events: $$ P(A \cup B \mid C) = P(A \mid C) + P(B \mid C) $$

# %%
business_manage_female = gender_vs_major.loc['Female', ['International Business', 'Management']].sum() / gender_vs_major.loc['Female', 'Total'] * 100
print(f"Out of the 33 female students, 4 are majoring in International Business and 4 are majoring in Management.\n"
      f"Hence the conditional probability that given a female student is randomly chosen, she is majoring in "
      f"international business or management is {round(business_manage_female, 2)}%.")
# Out:
# Out of the 33 female students, 4 are majoring in International Business and 4 are majoring in Management.
# Hence the conditional probability that given a female student is randomly chosen, she is majoring in international business or management is 24.24%.

# %% [markdown]
# ## 2.6.  Construct a contingency table of Gender and Intent to Graduate at 2 levels (Yes/No). The Undecided students are not considered now and the table is a 2x2 table. Do you think the graduate intention and being female are independent events?

# %%
gender_vs_intent_2_levels = survey_df.loc[survey_df['Grad Intention'] != 'Undecided', ['Gender', 'Grad Intention']]
gender_vs_intent_2_levels = pd.crosstab(index=gender_vs_intent_2_levels['Gender'], 
                                        columns=gender_vs_intent_2_levels['Grad Intention'], 
                                        margins=True, margins_name='Total')
gender_vs_intent_2_levels
# Out:
# Grad Intention  No  Yes  Total
# Gender
# Female           9   11     20
# Male             3   17     20
# Total           12   28     40

# %% [markdown]
# For independent events: $$ P(A \cap B) = P(A)P(B) $$

# %%
female_prob = gender_vs_intent_2_levels.loc['Female', 'Total'] / gender_vs_intent_2_levels.loc['Total', 'Total']
yes_intent_prob = gender_vs_intent_2_levels.loc['Total', 'Yes'] / gender_vs_intent_2_levels.loc['Total', 'Total']
yes_intent_and_female = gender_vs_intent_2_levels.loc['Female', 'Yes'] / gender_vs_intent_2_levels.loc['Total', 'Total']
print("Out of the 40 students, 20 are male, 28 intent to graduate, and 11 are both female and intent to graduate.\n")

if yes_intent_and_female == (female_prob * yes_intent_prob):
    print("Hence using the above mentioned formula we find that the graduate intention and being female are independent events.")
else:
    print("Hence using the above mentioned formula we find that the graduate intention and being female are not independent events.")
# Out:
# Out of the 40 students, 20 are male, 28 intent to graduate, and 11 are both female and intent to graduate.
#
# Hence using the above mentioned formula we find that the graduate intention and being female are not independent events.

# %% [markdown]
# ## 2.7. Note that there are four numerical (continuous) variables in the data set, GPA, Salary, Spending, and Text Messages.<br/>Answer the following questions based on the data

# %% [markdown]
# ### 2.7.1. If a student is chosen randomly, what is the probability that his/her GPA is less than 3?

# %%
gpa_less_than_3_prob = survey_df[survey_df['GPA'] < 3].shape[0] / survey_df.shape[0] * 100
print(f"Out of the 62 students, 17 students have GPA less than 3.\n"
      f"Hence if a student is chosen randomly, the probability that his/her GPA is less than 3 is {round(gpa_less_than_3_prob, 2)}%.")
# Out:
# Out of the 62 students, 17 students have GPA less than 3.
# Hence if a student is chosen randomly, the probability that his/her GPA is less than 3 is 27.42%.

# %% [markdown]
# ### 2.7.2. Find the conditional probability that a randomly selected male earns 50 or more. Find the conditional probability that a randomly selected female earns 50 or more.

# %%
male_salary_more_50 = survey_df[(survey_df['Gender'] == 'Male') & (survey_df['Salary'] >= 50)].shape[0] / survey_df[survey_df['Gender'] == 'Male'].shape[0] * 100
print(f"Out of the 29 male students, 14 students have salaries more than or equal to 50.\n"
      f"Hence the conditional probability that a randomly selected male earns 50 or more is {round(male_salary_more_50, 2)}%.")
# Out:
# Out of the 29 male students, 14 students have salaries more than or equal to 50.
# Hence the conditional probability that a randomly selected male earns 50 or more is 48.28%.

# %%
female_salary_more_50 = survey_df[(survey_df['Gender'] == 'Female') & (survey_df['Salary'] >= 50)].shape[0] / survey_df[survey_df['Gender'] == 'Female'].shape[0] * 100
print(f"Out of the 33 female students, 18 students have salaries more than or equal to 50.\n"
      f"Hence the conditional probability that a randomly selected female earns 50 or more is {round(female_salary_more_50, 2)}%.")
# Out:
# Out of the 33 female students, 18 students have salaries more than or equal to 50.
# Hence the conditional probability that a randomly selected female earns 50 or more is 54.55%.

# %% [markdown]
# ## 2.8. Note that there are four numerical (continuous) variables in the data set, GPA, Salary, Spending, and Text Messages. For each of them comment whether they follow a normal distribution. Write a note summarizing your conclusions., marker='o', fmt='b'

# %%
survey_df.hist(column=['GPA', 'Salary', 'Spending', 'Text Messages'], 
                  figsize=(12, 6), bins=8, layout=(2, 2))
plt.figtext(s='Distribution of Continous Variables in Survey dataset', x=0.5, y=1, ha='center', size='xx-large')
plt.tight_layout();

# %% [markdown]
# Theoretically the mean, median and mode of a normal distribution are equal.

# %% [markdown]
# ### Distribution of GPA

# %%
gpa_mean = survey_df['GPA'].mean()
gpa_median = survey_df['GPA'].median()
gpa_mode = survey_df['GPA'].mode()
gpa_std = survey_df['GPA'].std()
print(f"For the GPA variable:\n"
      f"Mean = {round(gpa_mean, 1)}\n"
      f"Median = {round(gpa_median, 1)}\n"
      f"Mode = [{gpa_mode[0]}, {gpa_mode[1]}, {gpa_mode[2]}]")
# Out:
# For the GPA variable:
# Mean = 3.1
# Median = 3.2
# Mode = [3.0, 3.1, 3.4]

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7))
sm.qqplot(survey_df['GPA'], line='45', loc=gpa_mean, scale=gpa_std, ax=ax, marker='o', fmt='b')
plt.title('QQ-Plot for GPA');

# %% [markdown]
# From the above outputs we can conclude that the __GPA__ variable in the Survey dataset approximately __follows a normal distribution__. This can also be verified from the above histogram.

# %% [markdown]
# ### Distribution of Salary

# %%
salary_mean = survey_df['Salary'].mean()
salary_median = survey_df['Salary'].median()
salary_mode = survey_df['Salary'].mode()
salary_std = survey_df['Salary'].std()
print(f"For the Salary variable:\n"
      f"Mean = {round(salary_mean, 1)}\n"
      f"Median = {round(salary_median, 1)}\n"
      f"Mode = {salary_mode[0]}")
# Out:
# For the Salary variable:
# Mean = 48.5
# Median = 50.0
# Mode = 40.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7))
sm.qqplot(survey_df['Salary'], line='45', loc=salary_mean, scale=salary_std, ax=ax, marker='o', fmt='b')
plt.title('QQ-Plot for Salary');

# %% [markdown]
# The mean, median and mode of Salary are very different from each other but its QQ-Plot is close to the straight line. Hence the __Salary__ variable approximately __follows a normal distribution__. This can also be verified from the above histogram.

# %% [markdown]
# ### Distribution of Spending

# %%
spend_mean = survey_df['Spending'].mean()
spend_median = survey_df['Spending'].median()
spend_mode = survey_df['Spending'].mode()
spend_std = survey_df['Spending'].std()
print(f"For the Spending variable:\n"
      f"Mean = {round(spend_mean, 1)}\n"
      f"Median = {round(spend_median, 1)}\n"
      f"Mode = {spend_mode[0]}")
# Out:
# For the Spending variable:
# Mean = 482.0
# Median = 500.0
# Mode = 500

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7))
sm.qqplot(survey_df['Spending'], line='45', loc=spend_mean, scale=spend_std, ax=ax, marker='o', fmt='b')
plt.title('QQ-Plot for Spending');

# %% [markdown]
# Even though the mean, median and mode of Spending are close to each other, its QQ-Plot varies a lot from the straight line.Hence the __Spending__ variable __does not follows a normal distribution__. This can also be verified from the above histogram.

# %% [markdown]
# ### Distribution of Text Messages

# %%
sms_mean = survey_df['Text Messages'].mean()
sms_median = survey_df['Text Messages'].median()
sms_mode = survey_df['Text Messages'].mode()
sms_std = survey_df['Text Messages'].std()
print(f"For the Text Messages variable:\n"
      f"Mean = {round(sms_mean, 1)}\n"
      f"Median = {round(sms_median, 1)}\n"
      f"Mode = {sms_mode[0]}")
# Out:
# For the Text Messages variable:
# Mean = 246.2
# Median = 200.0
# Mode = 300

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7))
sm.qqplot(survey_df['Text Messages'], line='45', loc=sms_mean, scale=sms_std, ax=ax, marker='o', fmt='b')
plt.title('QQ-Plot for Text Messages');

# %% [markdown]
# As the mean, median and mode of Text Messages variable are very different from each other and its QQ-Plot is not close to the straight line, the __Text Messages__ variable __does not follows a normal distribution__. This can also be verified from the above histogram.

# %% [markdown]
# ### Conclusion
# 1. The variables $\color{green}{\textit{GPA}}$ and $\color{green}{\textit{Salary}}$ approximately follow a normal distribution.
# 2. The variables $\color{red}{\textit{Spending}}$ and $\color{red}{\textit{Text Messages}}$ does not follow a normal distribution.
